# %% [markdown]
# ## Logistic distribution
# ### Vicente Pinochet

# %%
from numpy import random
import numpy as np

# %%
from scipy.stats import logistic

# %%
random.logistic(loc=0.0, scale=1.0, size=None)
# Out:
# 0.41535689905352485

# %%
loc, scale, bins = 20, 1 , 500
s = np.random.logistic(loc, scale, bins)
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s)

# %%
def logist(x, loc, scale):
    return np.exp((loc-x)/scale)/(scale*(1+np.exp((loc-x)/scale))**2)
lgst_val = logist(bins, loc, scale)
plt.plot(bins, lgst_val * count.max() / lgst_val.max())
plt.show()

# %% [markdown]
# ### A real world example of a logistic distribution is the spread of epidemics like the Covid-19.
# ### Also in Technology - to describe how technologies become popular and compete with each other
